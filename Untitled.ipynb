# %%
# Introduction

# What are cryptocurrencies?

# What is blockchain?

# What is the purpose of this project?

# %%
import datetime as dt
import numpy as np
import pandas as pd
import requests as req

from bs4 import BeautifulSoup as bs4
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters

# !pip install html5lib
# !pip install lxml
# Out:
# Requirement already satisfied: html5lib in /opt/conda/lib/python3.7/site-packages (1.0.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /opt/conda/lib/python3.7/site-packages (from html5lib) (1.12.0)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.7/site-packages (4.4.2)

# %%
# Data Collection

# What is data collection?

# Who are we getting data from?

# How will we get this data?

# %%
# https://coinmetrics.io/data-downloads/
btc = pd.read_csv('data/btc.csv')
eth = pd.read_csv('data/eth.csv')
xrp = pd.read_csv('data/xrp.csv')
ltc = pd.read_csv('data/ltc.csv')
bch = pd.read_csv('data/bch.csv')
# coinmarketcap_url = "https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20191208"
# r = req.get(coinmarketcap_url)
# root = bs4(r.content, 'html.parser')
# thead = root.find('thead')
# tbody = root.find('tbody')
# table = '<table>' + str(thead) + str(tbody) + '</table>'
# coinmarketcap = pd.read_html(str(table))[0]
# coinmarketcap.to_csv('coinmarketcap.csv', index=False)
coinmarketcap = pd.read_csv('data/coinmarketcap.csv')
# https://trends.google.com/trends/explore?date=2019-04-01%202019-11-30&geo=US&q=Bitcoin
googletrends = pd.read_csv('data/multiTimeline.csv')

# %%
# Data Cleaning

# What is data cleaning?

# How will we clean data?

# %%
# https://coinmetrics.io/community-data-dictionary/
# Cleaning Coinmetrics
def clean_coinmetrics(df):
    dates = []
    for i, row in df.iterrows():
        dates.append(dt.datetime.strptime(row['date'], '%Y-%m-%d').date())
    df['date'] = dates
    df = df.dropna(subset=['CapMrktCurUSD'])
    df = df.reset_index(drop=True)
    return df

# Bitcoin
btc = clean_coinmetrics(btc)

# Ethereum
eth = clean_coinmetrics(eth)

# Ripple
xrp = clean_coinmetrics(xrp)

# Bitcoin Cash
bch = clean_coinmetrics(bch)

#Litecoin
ltc = clean_coinmetrics(ltc)

# %%
# Cleaning CoinMarketCap
coinmarketcap_dates = []
for i, row in coinmarketcap.iterrows():
    coinmarketcap_dates.append(dt.datetime.strptime(row['Date'], '%b %d, %Y').date())
coinmarketcap['Date'] = coinmarketcap_dates
coinmarketcap = coinmarketcap.rename(columns={'Date':'date', 'Open*':'open', 'High':'high', 'Low':'low', \
                                              'Close**':'close', 'Volume':'volume', 'Market Cap':'marketCap'})
coinmarketcap = coinmarketcap.sort_values(by='date')
coinmarketcap = coinmarketcap.reset_index(drop=True)

# %%
# Cleaning Google Trends
googletrends = googletrends.drop('Day')
googletrends = googletrends.reset_index()
googletrends = googletrends.rename(columns={'index':'date', 'Category: All categories':'searchPopularity'})
googletrends_dates = []
googletrends_search = []
for i, row in googletrends.iterrows():
    googletrends_dates.append(dt.datetime.strptime(row['date'], '%Y-%m-%d').date())
    googletrends_search.append(int(row['searchPopularity']))
googletrends['date'] = googletrends_dates
googletrends['searchPopularity'] = googletrends_search

# %%
btc.head()
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 0  2010-07-18      860.0   172.0     136889.0       795.866279  146.038332
# 1  2010-07-19      929.0   174.0     139254.0       800.310345   62.565130
# 2  2010-07-20      936.0   181.0     197425.0      1090.745856   45.106630
# 3  2010-07-21      784.0   207.0     124991.0       603.821256   38.357560
# 4  2010-07-22      594.0   176.0     100750.0       572.443182   25.132348
#
#    CapMrktCurUSD   CapRealUSD    DiffMean  FeeMeanNtv  ...  TxTfrValAdjUSD  \
# 0  295959.152000  2026.585401  181.543289    0.003185  ...     1474.778412
# 1  279285.200000  4463.911468  181.543289    0.000150  ...     3251.693384
# 2  259000.404990  5741.958660  181.543289    0.000000  ...     1200.497201
# 3  275266.471297  7176.328942  181.543289    0.000000  ...     1649.915979
# 4  203749.573975  8107.064743  181.543289    0.000000  ...     1932.368865
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# 0        48.783737         4.187596           1.850        0.158804
# 1        86.951152         7.025653           2.625        0.212100
# 2        42.528835         3.178423           1.375        0.102762
# 3        71.822334         5.687816          18.500        1.465068
# 4       112.714622         6.590397           1.010        0.059054
#
#    TxTfrValNtv  TxTfrValUSD  VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# 0     19318.36  1658.288022            NaN           NaN           NaN
# 1     44518.99  3597.134392            NaN           NaN           NaN
# 2     31386.28  2345.676511            NaN           NaN           NaN
# 3     27077.02  2144.306726            NaN           NaN           NaN
# 4     38773.83  2267.096549            NaN           NaN           NaN
#
# [5 rows x 40 columns]

# %%
btc.columns
# Out:
# Index(['date', 'AdrActCnt', 'BlkCnt', 'BlkSizeByte', 'BlkSizeMeanByte',
#        'CapMVRVCur', 'CapMrktCurUSD', 'CapRealUSD', 'DiffMean', 'FeeMeanNtv',
#        'FeeMeanUSD', 'FeeMedNtv', 'FeeMedUSD', 'FeeTotNtv', 'FeeTotUSD',
#        'IssContNtv', 'IssContPctAnn', 'IssContUSD', 'IssTotNtv', 'IssTotUSD',
#        'NVTAdj', 'NVTAdj90', 'PriceBTC', 'PriceUSD', 'ROI1yr', 'ROI30d',
#        'SplyCur', 'TxCnt', 'TxTfrCnt', 'TxTfrValAdjNtv', 'TxTfrValAdjUSD',
#        'TxTfrValMeanNtv', 'TxTfrValMeanUSD', 'TxTfrValMedNtv',
#        'TxTfrValMedUSD', 'TxTfrValNtv', 'TxTfrValUSD', 'VtyDayRet180d',
#        'VtyDayRet30d', 'VtyDayRet60d'],
#       dtype='object')

# %%
eth.head()
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMrktCurUSD  \
# 0  2015-08-08       1208    5256      3508878       667.594749   8.676871e+07
# 1  2015-08-09       1113    5123      3167541       618.298068   8.680133e+07
# 2  2015-08-10       1430    5255      3316883       631.186108   8.683471e+07
# 3  2015-08-11       2697    5280      3653834       692.014015   7.166698e+07
# 4  2015-08-12       1219    5124      3348157       653.426425   9.327472e+07
#
#        DiffMean  FeeMeanNtv  FeeMeanUSD  FeeMedNtv  ...  TxTfrValAdjUSD  \
# 0  1.586124e+12    0.023638    0.028365   0.001243  ...    1.609869e+07
# 1  1.709480e+12    0.010609    0.012730   0.001223  ...    1.233428e+06
# 2  1.837696e+12    0.015300    0.018359   0.001228  ...    1.742816e+06
# 3  2.036391e+12    0.002279    0.002256   0.001218  ...    1.190079e+06
# 4  2.207080e+12    0.016005    0.020615   0.001244  ...    8.199163e+05
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# 0      5101.056788      6121.217135        1.000000        1.199990
# 1       921.287176      1105.535399       12.999397       15.599147
# 2       804.829350       965.787172        0.598340        0.718002
# 3       294.681751       291.734933        0.054538        0.053993
# 4       382.281012       492.377944       10.000000       12.880000
#
#     TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# 0  1.358411e+07  1.630080e+07            NaN           NaN           NaN
# 1  1.166350e+06  1.399608e+06            NaN           NaN           NaN
# 2  1.672435e+06  2.006906e+06            NaN           NaN           NaN
# 3  1.487259e+06  1.472386e+06            NaN           NaN           NaN
# 4  7.523290e+05  9.689998e+05            NaN           NaN           NaN
#
# [5 rows x 38 columns]

# %%
xrp.head()
# Out:
#          date  AdrActCnt  BlkCnt  CapMrktCurUSD  FeeMeanNtv    FeeMeanUSD  \
# 0  2014-08-15       1276   17490   5.598614e+08    0.000139  7.756546e-07
# 1  2014-08-16       1173   18123   5.582654e+08    0.000022  1.227849e-07
# 2  2014-08-17       1057   16365   8.397825e+08    0.000023  1.937712e-07
# 3  2014-08-18       1431   17624   4.684718e+08    0.000024  1.142083e-07
# 4  2014-08-19       1364   17762   4.828313e+08    0.000022  1.039923e-07
#
#    FeeMedNtv     FeeMedUSD  FeeTotNtv  FeeTotUSD  ...  TxTfrValAdjUSD  \
# 0   0.000012  6.718338e-08  42.008760   0.235191  ...   279963.355147
# 1   0.000012  6.699186e-08   5.652502   0.031556  ...    82126.340512
# 2   0.000012  1.007739e-07   5.922235   0.049734  ...    48013.164662
# 3   0.000012  5.621663e-08   7.517089   0.035215  ...   230092.361958
# 4   0.000012  5.793977e-08   6.050629   0.029214  ...   464915.362962
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# 0     84961.779658       475.668298           362.2        2.027818
# 1     24317.687381       135.757265            20.0        0.111653
# 2     10747.993361        90.259786            28.0        0.235139
# 3     45362.235778       212.509346            50.0        0.234236
# 4    140849.330619       680.064842           100.0        0.482831
#
#     TxTfrValNtv    TxTfrValUSD  VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# 0  5.344096e+07  299195.359231            NaN           NaN           NaN
# 1  1.485811e+07   82947.688663            NaN           NaN           NaN
# 2  6.233836e+06   52350.675752            NaN           NaN           NaN
# 3  4.953556e+07  232060.206141            NaN           NaN           NaN
# 4  1.129612e+08  545412.003221            NaN           NaN           NaN
#
# [5 rows x 30 columns]

# %%
bch.head()
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 0  2017-08-01     308149      89     68606659     7.708613e+05   25.851468
# 1  2017-08-02      16751       7      4320573     6.172247e+05   24.743938
# 2  2017-08-03      80506      35     17829726     5.094207e+05   16.215795
# 3  2017-08-04      88105      19     21606631     1.137191e+06    8.802462
# 4  2017-08-05      44381      13      9964347     7.664882e+05    8.208400
#
#    CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  ...  TxTfrValAdjUSD  \
# 0   5.411500e+09  2.093305e+08  8.602220e+11    0.000676  ...    2.556305e+08
# 1   5.653824e+09  2.284933e+08  7.314358e+11    0.001152  ...    3.304812e+07
# 2   4.994964e+09  3.080308e+08  2.307405e+11    0.000894  ...    1.584445e+08
# 3   3.230499e+09  3.669995e+08  2.255056e+11    0.000807  ...    1.751326e+08
# 4   3.188358e+09  3.884262e+08  2.255056e+11    0.000762  ...    1.173970e+08
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# 0         7.186771      2359.617548        0.013590        4.461976
# 1        23.399380      8026.652990        0.985277      337.978213
# 2        27.968099      8475.623036        0.974834      295.419585
# 3        32.142174      6299.628688        0.957377      187.638918
# 4        45.578095      8816.353395        0.999840      193.403115
#
#     TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# 0  1.494360e+06  4.906400e+08            NaN           NaN           NaN
# 1  1.504112e+05  5.159533e+07            NaN           NaN           NaN
# 2  1.050090e+06  3.182257e+08            NaN           NaN           NaN
# 3  1.334061e+06  2.614661e+08            NaN           NaN           NaN
# 4  8.936041e+05  1.728534e+08            NaN           NaN           NaN
#
# [5 rows x 40 columns]

# %%
ltc.head()
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 0  2013-04-01      11649     742      3973650      5355.323450   14.716638
# 1  2013-04-02      17131     902      5321624      5899.804878    8.935656
# 2  2013-04-03      17130     896      4728976      5277.875000    7.131525
# 3  2013-04-04      16542     772      5201142      6737.230570    7.224639
# 4  2013-04-05      16353     786      5973976      7600.478372    4.826198
#
#    CapMrktCurUSD    CapRealUSD    DiffMean  FeeMeanNtv  ...  TxTfrValAdjUSD  \
# 0   2.466248e+07  1.675823e+06   99.963803    0.065012  ...    2.782745e+06
# 1   7.524414e+07  8.420663e+06  100.543923    0.063475  ...    9.850541e+06
# 2   7.545076e+07  1.057989e+07  125.505161    0.062112  ...    4.936497e+06
# 3   8.850532e+07  1.225048e+07  153.168086    0.069217  ...    4.456535e+06
# 4   6.121712e+07  1.268433e+07  153.168086    0.070585  ...    2.741063e+06
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# 0       242.435717       367.697476        5.971298        9.056550
# 1       184.623468       851.952504        5.337660       24.630850
# 2        84.532794       390.080018        5.002255       23.083108
# 3        64.393878       347.740104        4.686453       25.307805
# 4        84.983637       316.671868        4.482181       16.701810
#
#     TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# 0  3.053478e+06  4.631150e+06            NaN           NaN           NaN
# 1  3.586126e+06  1.654833e+07            NaN           NaN           NaN
# 2  1.630299e+06  7.523083e+06            NaN           NaN           NaN
# 3  1.258578e+06  6.796580e+06            NaN           NaN           NaN
# 4  1.551801e+06  5.782428e+06            NaN           NaN           NaN
#
# [5 rows x 40 columns]

# %%
coinmarketcap.head()
# Out:
#          date    open    high     low   close  volume   marketCap
# 0  2013-04-28  135.30  135.98  132.10  134.21       0  1488566728
# 1  2013-04-29  134.44  147.49  134.00  144.54       0  1603768865
# 2  2013-04-30  144.00  146.93  134.05  139.00       0  1542813125
# 3  2013-05-01  139.00  139.89  107.72  116.99       0  1298954594
# 4  2013-05-02  116.38  125.60   92.28  105.21       0  1168517495

# %%
googletrends.head()
# Out:
#          date  searchPopularity
# 0  2019-04-01                15
# 1  2019-04-02                37
# 2  2019-04-03                41
# 3  2019-04-04                26
# 4  2019-04-05                21

# %%
# Data Analysis

# %%
# Case Study 1: Bitcoin Bubbles

# What is a bubble?

# Can we predict the next bubble?

# Analyzing the four biggest Bitcoin bubbles
bubble1 = btc[(btc.date > dt.date(2010, 12, 1)) & (btc.date < dt.date(2012, 1, 1))]
bubble2 = btc[(btc.date > dt.date(2013,  1, 1)) & (btc.date < dt.date(2013, 7, 1))]
bubble3 = btc[(btc.date > dt.date(2013,  9, 1)) & (btc.date < dt.date(2014, 3, 1))]
bubble4 = btc[(btc.date > dt.date(2016, 12, 1)) & (btc.date < dt.date(2019, 4, 1))]

# %%
plt.plot(bubble4.date, bubble4.PriceUSD)

# %%
plt.plot(bubble2.date, bubble2.PriceUSD)

# %%
plt.plot(bubble3.date, bubble3.PriceUSD)

# %%
plt.plot(bubble4.date, bubble4.PriceUSD)

# %%
# Case Study 2: Top 5 Cryptocurrencies

# What are the top 5 cryptocurrencies?

# Bitcoin, Ethereum, Ripple, Bitcoin Cash, Litecoin

# %%
top5 = [btc, eth, xrp, bch, ltc]

for df in top5:
    df_current = df[df.date >= dt.date(2017, 8, 1)]
    plt.plot(df_current['date'], df_current['CapMrktCurUSD'])
plt.legend(['btc', 'eth', 'xrp', 'bch', 'ltc'])

# %%
top5 = [btc, eth, xrp, bch, ltc]
top5_labels = ['btc', 'eth', 'xrp', 'bch', 'ltc']

for df in top5:
    df_current = df[(df.date >= dt.date(2017, 8, 1)) & (df.date < dt.date(2018, 9, 1))]
    plt.plot(df_current['date'], df_current['CapMrktCurUSD'])
plt.legend(top5_labels)

# %%
for df in top5:
    df_current = df[(df.date >= dt.date(2018, 9, 1)) & (df.date < dt.date(2019, 11, 1))]
    plt.plot(df_current['date'], df_current['CapMrktCurUSD'])
plt.legend(['btc', 'eth', 'xrp', 'bch', 'ltc'])

# %%
def get_avg_marketcaps(dfs, start, end):
    marketcaps = []
    for df in dfs:
        period = df[(df.date >= start) & (df.date <= end)]
        marketcaps.append(period['CapMrktCurUSD'].mean())
    return marketcaps

marketcaps1 = get_avg_marketcaps(top5, dt.date(2017, 12, 1), dt.date(2018, 1, 30))


plt.pie(marketcaps1)
plt.legend(top5_labels)

# %%
marketcaps2 = get_avg_marketcaps(top5, dt.date(2019, 7, 1), dt.date(2019, 12, 1))
plt.pie(marketcaps2)
plt.legend(top5_labels)

# %%
# Case Study 3: Finding Correlations With Bitcoin Price

# What is linear regression?

# How can we use linear regression to find relationships with Bitcoin Price?

# %%
# Calculate 14 day RSI and 26 EMA
indicators = coinmarketcap[['date', 'close']]

# %%
indicators.head()
# Out:
#          date   close
# 0  2013-04-28  134.21
# 1  2013-04-29  144.54
# 2  2013-04-30  139.00
# 3  2013-05-01  116.99
# 4  2013-05-02  105.21

# %%
change = []
for i, row in indicators.iterrows():
    x = row.close - indicators.loc[i-1, 'close'] if i > 0 else np.nan
    change.append(x)
indicators['change'] = change
indicators = indicators.dropna()
indicators = indicators.reset_index(drop=True)
indicators['upMove'] = [x if x >= 0 else 0 for x in indicators['change']]
indicators['downMove'] = [abs(x) if x < 0 else 0 for x in indicators['change']]
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
avgUpMove = []
for i, row in indicators.iterrows():
    x = np.nan
    if i == 13:
        x = indicators[0:14]['upMove'].mean()
    elif i > 13:
        x = (avgUpMove[i-1] * 13 + row['upMove']) / 14
    avgUpMove.append(x)
indicators['avgUpMove'] = avgUpMove

# %%
avgDownMove = []
for i, row in indicators.iterrows():
    x = np.nan
    if i == 13:
        x = indicators[0:14]['downMove'].mean()
    elif i > 13:
        x = (avgDownMove[i-1] * 13 + row['downMove']) / 14
    avgDownMove.append(x)
indicators['avgDownMove'] = avgDownMove

# %%
indicators['RS'] = indicators['avgUpMove'] / indicators['avgDownMove']
indicators['RSI'] = 100 - (100 / (indicators['RS'] + 1))

# %%
# Calculate 12 day EMA
EMA12 = []
for i, row in indicators.iterrows():
    x = np.nan
    if i == 11:
        x = indicators[0:12]['close'].mean()
    elif i > 11:
        x = (row['close'] - EMA12[i-1]) * (2 / 13) + EMA12[i-1]
    EMA12.append(x)
indicators['EMA12'] = EMA12

# %%
# Calculate 26 day EMA
EMA26 = []
for i, row in indicators.iterrows():
    x = np.nan
    if i == 25:
        x = indicators[0:26]['close'].mean()
    elif i > 25:
        x = (row['close'] - EMA26[i-1]) * (2 / 27) + EMA26[i-1]
    EMA26.append(x)
indicators['EMA26'] = EMA26

# %%
# Calculate MACD Line
indicators['MACD'] = indicators['EMA26'] - indicators['EMA12']

# %%
indicators = indicators.dropna()

# %%
# Create new dataframe for 2
btc2019 = pd.merge(googletrends, indicators[['date', 'close', 'change', 'RSI', 'MACD']], on='date')
btc2019 = pd.merge(btc2019, btc, on='date')

# %%
btc2019
# Out:
#            date  searchPopularity    close  change        RSI        MACD  \
# 0    2019-04-01                15  4158.18   52.78  66.775952  -57.501799
# 1    2019-04-02                37  4879.88  721.70  87.341929 -117.811812
# 2    2019-04-03                41  4973.02   93.14  88.344663 -171.150633
# 3    2019-04-04                26  4922.80  -50.22  84.459648 -206.983719
# 4    2019-04-05                21  5036.68  113.88  85.966698 -241.783730
# ..          ...               ...      ...     ...        ...         ...
# 239  2019-11-26                20  7218.37   72.24  28.992053  440.730942
# 240  2019-11-27                19  7531.66  313.29  37.512070  423.443120
# 241  2019-11-28                16  7463.11  -68.55  36.480636  410.541343
# 242  2019-11-29                15  7761.24  298.13  43.727493  371.972130
# 243  2019-11-30                15  7569.63 -191.61  40.527217  352.800215
#
#      AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  ...  TxTfrValAdjUSD  \
# 0     697929.0   136.0  164514347.0     1.209664e+06  ...    1.394325e+09
# 1     879271.0   157.0  190457408.0     1.213105e+06  ...    2.380321e+09
# 2     856707.0   142.0  177143791.0     1.247491e+06  ...    2.065022e+09
# 3     802957.0   140.0  170246973.0     1.216050e+06  ...    1.850883e+09
# 4     873077.0   158.0  195325569.0     1.236238e+06  ...    1.697966e+09
# ..         ...     ...          ...              ...  ...             ...
# 239   784964.0   122.0  152896582.0     1.253251e+06  ...    2.210674e+09
# 240   812540.0   139.0  161725316.0     1.163491e+06  ...    2.143191e+09
# 241   716192.0   163.0  145203756.0     8.908206e+05  ...    1.430809e+09
# 242   730014.0   136.0  143846242.0     1.057693e+06  ...    1.942321e+09
# 243   683831.0   126.0  135152150.0     1.072636e+06  ...    1.775029e+09
#
#      TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# 0           1.059335      4383.972893        0.014960       61.910730
# 1           1.699154      8332.174774        0.017790       87.237169
# 2           1.220121      6052.078576        0.016015       79.440525
# 3           1.212850      5956.635000        0.013434       65.976180
# 4           0.935780      4709.991379        0.010520       52.949532
# ..               ...              ...             ...             ...
# 239         0.949476      6803.409291        0.010979       78.671204
# 240         1.002325      7544.367011        0.011137       83.824650
# 241         0.726430      5401.977986        0.010405       77.378798
# 242         0.939853      7281.735927        0.010856       84.108127
# 243         0.903841      6829.600183        0.009612       72.633912
#
#       TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# 0    8.019710e+05  3.318891e+09       0.033875      0.012901      0.020865
# 1    1.472135e+06  7.218938e+09       0.036209      0.032983      0.029949
# 2    9.878174e+05  4.899799e+09       0.036218      0.032454      0.029957
# 3    9.459104e+05  4.645621e+09       0.036222      0.032207      0.029913
# 4    7.982371e+05  4.017707e+09       0.036274      0.032327      0.029994
# ..            ...           ...            ...           ...           ...
# 239  6.746215e+05  4.833958e+09       0.040647      0.023165      0.032532
# 240  7.023465e+05  5.286466e+09       0.040736      0.025318      0.033201
# 241  4.963224e+05  3.690820e+09       0.040745      0.025073      0.033168
# 242  6.261245e+05  4.851049e+09       0.040829      0.026341      0.033425
# 243  5.741101e+05  4.338087e+09       0.040563      0.026570      0.033560
#
# [244 rows x 45 columns]

# %%
btc2019.columns
# Out:
# Index(['date', 'searchPopularity', 'close', 'change', 'RSI', 'MACD',
#        'AdrActCnt', 'BlkCnt', 'BlkSizeByte', 'BlkSizeMeanByte', 'CapMVRVCur',
#        'CapMrktCurUSD', 'CapRealUSD', 'DiffMean', 'FeeMeanNtv', 'FeeMeanUSD',
#        'FeeMedNtv', 'FeeMedUSD', 'FeeTotNtv', 'FeeTotUSD', 'IssContNtv',
#        'IssContPctAnn', 'IssContUSD', 'IssTotNtv', 'IssTotUSD', 'NVTAdj',
#        'NVTAdj90', 'PriceBTC', 'PriceUSD', 'ROI1yr', 'ROI30d', 'SplyCur',
#        'TxCnt', 'TxTfrCnt', 'TxTfrValAdjNtv', 'TxTfrValAdjUSD',
#        'TxTfrValMeanNtv', 'TxTfrValMeanUSD', 'TxTfrValMedNtv',
#        'TxTfrValMedUSD', 'TxTfrValNtv', 'TxTfrValUSD', 'VtyDayRet180d',
#        'VtyDayRet30d', 'VtyDayRet60d'],
#       dtype='object')

# %%
plt.plot(btc2019.date, btc2019.close)

# %%
plt.plot(btc2019.date, btc2019.searchPopularity)

# %%
plt.plot(btc2019.close, btc2019.searchPopularity, '.')

# %%
plt.plot(btc2019.close, btc2019.marketCap, '.')

# %%
plt.plot(btc2019.close, btc2019.volume, '.')

# %%
plt.plot(btc2019.close, btc2019.AdrActCnt, '.')

# %%
plt.plot(btc2019.close, btc2019.BlkSizeByte, '.')

# %%
plt.plot(btc2019.close, btc2019.CapMrktCurUSD, '.')
